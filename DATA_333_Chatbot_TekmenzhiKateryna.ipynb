# %%
#Ask for the customer's first and last name. Store the values input to a variable.
first_name = input("What is your first name? ")
last_name = input("What is your last name? ")

#Greet your customer using their full name.
print("Hello " + first_name + " " + last_name + "!")
print("Welcome to the Chatbot Store!")

#Provide a few sentence overview of your Chatbot program. Be creative - make some stuff up. Output it to the screen with a nice format of your choice. Make this as serious or as silly a scenario as you want it to be.
print("We sell chatbots that can help you with your daily tasks. Our chatbots can help you with your homework, help you with your chores, and even help you with your taxes! You can depend on our chatbots to help you with anything you need. Just ask our chatbots a question and they will answer it for you. Our chatbots are very smart and can answer any question you have. Our chatbots are also very friendly and will always be there for you. Our chatbots are the best in the world and you will not find better chatbots anywhere else. Our chatbots are also very affordable. You can purchase a chatbot for only $75. You can also purchase an optional Gold Support plan that gets you priority support for only $500/year for license purchases 1 - 50, $350/year for license purchases 51 - 99, and $250/year for license purchases 100+. Our chatbots are the best in the world and you will not find better chatbots anywhere else. ")
print()

#Ask if your customer would like to make a purchase.
answer = input("Would you like to make a purchase? (yes/no) ")
if answer == "yes":
    #Ask for their email address. Store the values input to a variable.
    email = input("What is your email address? ")
    #Ask for their phone number.  Store the values input to a variable.
    phone_number = input("What is your phone number? ")
    #Ask for how many chatbot licenses they would like to purchase. Store the values input to a variable.
    licenses = int(input("How many chatbot licenses would you like to purchase? "))
    #Ask if they would also like to purchase an optional Gold Support plan that gets them priority support.
    answer = input("Would you like to purchase an optional Gold Support plan that gets you priority support? (yes/no) ")
    if answer == "yes":
        #The Gold Support plan costs $500/year for license purchases 1 - 50.
        if licenses >= 1 and licenses <= 50:
            gold_support_plan = 500
        #The Gold Support plan costs $350/year for license purchases 51 - 99.
        elif licenses >= 51 and licenses <= 99:
            gold_support_plan = 350
        #The Gold Support plan costs $250/year for license purchases 100+.
        elif licenses >= 100:
            gold_support_plan = 250
        #Each chatbot license costs $75. Calculate and display their current total.  Store the values input to a variable.
        total = licenses * 75 + gold_support_plan
        print("Your total is $" + str(total) + ".")
        #Apply 10% tax for the total bill.
        tax = total * 0.1
        #Calculate the total amount due. Store the values input to a variable.
        total_due = total + tax
        print("Your total due is $" + str(total_due) + ".")
        #Ask for a credit card number.  Store the values input to a variable.
        credit_card_number = input("What is your credit card number? ")
        #Ask for a credit card expiration date. Store the values input to a variable.
        credit_card_expiration_date = input("What is your credit card expiration date? ")
        #Ask for a CVC number on the back of the credit card.  Store the values input to a variable.
        cvc_number = input("What is your CVC number? ")
        #Ask for a zip code. Store the values input to a variable.
        zip_code = input("What is your zip code? ")
        #Output a receipt using all of the variables you have input. Be sure to show the total license number, the amount for each license, the subtotal, tax, and total amount due.
        print("Thank you for being a Gold Support member " + first_name + " " + last_name + "!")
        print("=====================================")
        print("Here is your receipt:")
        print()
        print("Name: " + first_name + " " + last_name)
        print("Phone Number: " + phone_number)
        print("Email Address: " + email)
        print("Credit Card Number: " + credit_card_number)
        print("Credit Card Expiration Date: " + credit_card_expiration_date)
        print("CVC Number: " + cvc_number)
        print("Zip Code: " + zip_code)
        print("Total Licenses: " + str(licenses))
        print("Gold Support Plan: $" + str(gold_support_plan))
        print("Amount for Each License: $75")
        print("Subtotal: $" + str(total))
        print("Tax: $" + str(tax))
        print("Total Amount Due: $" + str(total_due))
    #If no - #Each chatbot license costs $75. Calculate and display their current total.  Store the values input to a variable.
    elif answer == "no":
        total = licenses * 75
        print("Your total is $" + str(total) + ".")
        #Apply 10% tax for the total bill.
        tax = total * 0.1
        #Calculate the total amount due. Store the values input to a variable.
        total_due = total + tax
        print("Your total due is $" + str(total_due) + ".")
        #Ask for a credit card number.  Store the values input to a variable.
        credit_card_number = input("What is your credit card number? ")
        #Ask for a credit card expiration date. Store the values input to a variable.
        credit_card_expiration_date = input("What is your credit card expiration date? ")
        #Ask for a CVC number on the back of the credit card.  Store the values input to a variable.
        cvc_number = input("What is your CVC number? ")
        #Ask for a zip code. Store the values input to a variable.
        zip_code = input("What is your zip code? ")
        #Output a receipt using all of the variables you have input. Be sure to show the total license number, the amount for each license, the subtotal, tax, and total amount due.
        print("Thank you for your purchase " + first_name + " " + last_name + "!")
        print("=====================================")
        print("Here is your receipt:")
        print()
        print("Name: " + first_name + " " + last_name)
        print("Phone Number: " + phone_number)
        print("Email Address: " + email)
        print("Credit Card Number: " + credit_card_number)
        print("Credit Card Expiration Date: " + credit_card_expiration_date)
        print("CVC Number: " + cvc_number)
        print("Zip Code: " + zip_code)
        print("Total Licenses: " + str(licenses))
        print("Amount for Each License: $75")
        print("Subtotal: $" + str(total))
        print("Tax: $" + str(tax))
        print("Total Amount Due: $" + str(total_due))
#If no - thank the customer by name and say goodbye.
elif answer == "no":
    print("Thank you for visiting the Chatbot Store " + first_name + " " + last_name + ". Have a nice day!")
#Ask the customer if they would like to restart the ChatBot.
answer = input("Would you like to restart the ChatBot? (yes/no) ")
if answer == "yes":
    #If yes - restart the ChatBot.
    print("Restarting ChatBot...")
    print()
    # %run DATA_333_Chatbot_TekmenzhiKateryna.ipynb
#If no - thank the customer by name and say goodbye.
elif answer == "no":
    print("Thank you for visiting the Chatbot Store " + first_name + " " + last_name + ". Have a nice day!")
# Out:
# What is your first name? kat
# What is your last name? tek
# Hello kat tek!
# Welcome to the Chatbot Store!
# We sell chatbots that can help you with your daily tasks. Our chatbots can help you with your homework, help you with your chores, and even help you with your taxes!
# Would you like to make a purchase? (yes/no) yes
# What is your email address? yitou
# What is your phone number? kg
# How many chatbot licenses would you like to purchase? 10
# Would you like to purchase an optional Gold Support plan that gets you priority support? (yes/no) yes
# Your total is $1250.
# Your total due is $1375.0.
# What is your credit card number? iyg
# What is your credit card expiration date? jf
# What is your CVC number? jg
# What is your zip code? yg
# Thank you for being a Gold Support member kat tek!
# ...
# Here is your receipt:
#
# Name: kat tek
# Phone Number: kg
# Email Address: yitou
# Credit Card Number: iyg
# Credit Card Expiration Date: jf
# CVC Number: jg
# Zip Code: yg
# ...
